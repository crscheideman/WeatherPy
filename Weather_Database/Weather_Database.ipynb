# %%
# import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from citipy import citipy

#import linear regression from the SciPy stats model
from scipy.stats import linregress

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

from datetime import datetime

# %%
# create a set of random latitude and longitude combos
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(-180.000, 180.000, size=2000)
lat_lngs = zip(lats, lngs)

# add lat and lngs to a list
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities = []
# identify the nearest city for each latitude and longitude combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # if the city is unique, then add to cities list
    if city not in cities:
        cities.append(city)

# %%
# starting url for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        print(city_weather)
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_descrip = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Current Description": city_descrip,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tiksi
# {'coord': {'lon': 128.87, 'lat': 71.69}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 41.99, 'feels_like': 34.74, 'temp_min': 41.99, 'temp_max': 41.99, 'pressure': 1021, 'humidity': 80, 'sea_level': 1021, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 7.74, 'deg': 127}, 'clouds': {'all': 46}, 'dt': 1598636038, 'sys': {'country': 'RU', 'sunrise': 1598642052, 'sunset': 1598701031}, 'timezone': 32400, 'id': 2015306, 'name': 'Tiksi', 'cod': 200}
# Processing Record 2 of Set 1 | itum-kale
# {'coord': {'lon': 45.58, 'lat': 42.74}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 64.94, 'feels_like': 62.46, 'temp_min': 64.94, 'temp_max': 64.94, 'pressure': 1014, 'humidity': 59, 'sea_level': 1014, 'grnd_level': 925}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 196}, 'clouds': {'all': 37}, 'dt': 1598636038, 'sys': {'country': 'RU', 'sunrise': 1598581109, 'sunset': 1598629180}, 'timezone': 10800, 'id': 555681, 'name': 'Itum-Kale', 'cod': 200}
# Processing Record 3 of Set 1 | kutum
# {'coord': {'lon': 24.67, 'lat': 14.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.12, 'feels_like': 77.63, 'temp_min': 79.12, 'temp_max': 79.12, 'pressure': 1008, 'humidity': 55, 'sea_level': 1008, 'grnd_level': 885}, 'visibility': 10000, 'wind': {'speed': 9.51, 'deg': 75}, 'clouds': {'all': 79}, 'dt': 1598636038, 'sys': {'country': 'SD', 'sunrise': 1598587766, 'sunset': 1598632558}, 'timezone': 7200, 'id': 371745, 'name': 'Kutum', 'cod': 200}
# Processing Record 4 of Set 1 | pochutla
# {'coord': {'lon': -96.47, 'lat': 15.74}, 'weather': [{'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 75.2, 'feels_like': 76.91, 'temp_min': 75.2, 'temp_max': 75.2, 'pressure': 1015, 'humidity': 69}, 'visibility': 1609, 'wind': {'speed': 5.82, 'deg': 280}, 'clouds': {'all': 90}, 'dt': 1598636038, 'sys': {'type': 1, 'id': 7096, 'country': 'MX', 'sunrise': 1598616774, 'sunset': 1598661685}, 'timezone': -18000, 'id': 3517970, 'name': 'Pochutla', 'cod': 200}
# Processing Record 5 of Set 1 | hithadhoo
# {'coord': {'lon': 73.08, 'lat': -0.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.48, 'feels_like': 80.11, 'temp_min': 79.48, 'temp_max': 79.48, 'pressure': 1012, 'humidity': 70, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 131}, 'clouds': {'all': 100}, 'dt': 1598635912, 'sys': {'country': 'MV', 'sunrise': 1598576768, 'sunset': 1598620324}, 'timezone': 18000, 'id': 1282256, 'name': 'Hithadhoo', 'cod': 200}
# Processing Record 6 of Set 1 | tahta
# {'coord': {'lon': 31.5, 'lat': 26.77}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 91.49, 'feels_like': 85.35, 'temp_min': 89.6, 'temp_max': 93.2, 'pressure': 1003, 'humidity': 23}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 330}, 'clouds': {'all': 0}, 'dt': 1598636039, 'sys': {'type': 1, 'id': 2548, 'country': 'EG', 'sunrise': 1598585523, 'sunset': 1598631523}, 'timezone': 7200, 'id': 347634, 'name': 'Ţahţā', 'cod': 200}
# Processing Record 7 of Set 1 | taolanaro
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 8 of Set 1 | barentsburg
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 9 of Set 1 | kroya
# {'coord': {'lon': 109.25, 'lat': -7.63}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 75.56, 'feels_like': 80.11, 'temp_min': 75.56, 'temp_max': 75.56, 'pressure': 1010, 'humidity': 88, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 7.09, 'deg': 102}, 'clouds': {'all': 57}, 'dt': 1598636039, 'sys': {'country': 'ID', 'sunrise': 1598654747, 'sunset': 1598697751}, 'timezone': 25200, 'id': 1639337, 'name': 'Kroya', 'cod': 200}
# Processing Record 10 of Set 1 | san juan
# {'coord': {'lon': -68.54, 'lat': -31.54}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.04, 'feels_like': 64.8, 'temp_min': 73.04, 'temp_max': 73.04, 'pressure': 1009, 'humidity': 20, 'sea_level': 1009, 'grnd_level': 937}, 'visibility': 10000, 'wind': {'speed': 7.7, 'deg': 140}, 'clouds': {'all': 0}, 'dt': 1598636039, 'sys': {'country': 'AR', 'sunrise': 1598612102, 'sunset': 1598652954}, 'timezone': -10800, 'id': 3837213, 'name': 'San Juan', 'cod': 200}
# Processing Record 11 of Set 1 | vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 75.06, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1019, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 90}, 'clouds': {'all': 40}, 'dt': 1598636039, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1598723533, 'sunset': 1598765472}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# Processing Record 12 of Set 1 | saint-philippe
# {'coord': {'lon': 55.77, 'lat': -21.36}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.99, 'feels_like': 66.38, 'temp_min': 57.99, 'temp_max': 73.4, 'pressure': 1019, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 100}, 'clouds': {'all': 75}, 'dt': 1598636039, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1598581793, 'sunset': 1598623606}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# Processing Record 13 of Set 1 | punta arenas
# {'coord': {'lon': -70.92, 'lat': -53.15}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 32, 'feels_like': 7.2, 'temp_min': 32, 'temp_max': 32, 'pressure': 995, 'humidity': 88}, 'visibility': 7000, 'wind': {'speed': 36.91, 'deg': 270, 'gust': 49.44}, 'clouds': {'all': 20}, 'dt': 1598635919, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1598614244, 'sunset': 1598651954}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# Processing Record 14 of Set 1 | souillac
# {'coord': {'lon': 57.52, 'lat': -20.52}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 72.55, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1020, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 90}, 'clouds': {'all': 75}, 'dt': 1598636040, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1598581335, 'sunset': 1598623224}, 'timezone': 14400, 'id': 933995, 'name': 'Souillac', 'cod': 200}
# Processing Record 15 of Set 1 | palmares do sul
# {'coord': {'lon': -50.51, 'lat': -30.26}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 74.08, 'feels_like': 75.54, 'temp_min': 74.08, 'temp_max': 74.08, 'pressure': 1014, 'humidity': 60, 'sea_level': 1014, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 2.75, 'deg': 75}, 'clouds': {'all': 62}, 'dt': 1598636040, 'sys': {'country': 'BR', 'sunrise': 1598607711, 'sunset': 1598648692}, 'timezone': -10800, 'id': 3455461, 'name': 'Palmares do Sul', 'cod': 200}
# Processing Record 16 of Set 1 | aykhal
# {'coord': {'lon': 111.5, 'lat': 66}, 'weather': [{'id': 711, 'main': 'Smoke', 'description': 'smoke', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 45.99, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1014, 'humidity': 34}, 'visibility': 5000, 'wind': {'speed': 2.24, 'deg': 0}, 'clouds': {'all': 75}, 'dt': 1598636040, 'sys': {'type': 1, 'id': 8846, 'country': 'RU', 'sunrise': 1598648389, 'sunset': 1598703029}, 'timezone': 32400, 'id': 2027296, 'name': 'Aykhal', 'cod': 200}
# Processing Record 17 of Set 1 | rungata
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 18 of Set 1 | mildura
# {'coord': {'lon': 142.15, 'lat': -34.2}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 43.38, 'feels_like': 36.25, 'temp_min': 42.8, 'temp_max': 44.01, 'pressure': 1028, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1598636040, 'sys': {'type': 1, 'id': 9550, 'country': 'AU', 'sunrise': 1598648049, 'sunset': 1598688661}, 'timezone': 36000, 'id': 2157698, 'name': 'Mildura', 'cod': 200}
# Processing Record 19 of Set 1 | mataura
# {'coord': {'lon': 168.86, 'lat': -46.19}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 45, 'feels_like': 35.94, 'temp_min': 45, 'temp_max': 45, 'pressure': 1008, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 194, 'gust': 21.99}, 'clouds': {'all': 37}, 'dt': 1598636041, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1598642425, 'sunset': 1598681466}, 'timezone': 43200, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# Processing Record 20 of Set 1 | bengkulu
# {'coord': {'lon': 102.27, 'lat': -3.8}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 76.26, 'feels_like': 80.28, 'temp_min': 76.26, 'temp_max': 76.26, 'pressure': 1009, 'humidity': 84, 'sea_level': 1009, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 7.38, 'deg': 119}, 'clouds': {'all': 47}, 'dt': 1598636041, 'sys': {'country': 'ID', 'sunrise': 1598656271, 'sunset': 1598699577}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# Processing Record 21 of Set 1 | narsaq
# {'coord': {'lon': -46.05, 'lat': 60.92}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 60.8, 'feels_like': 38.61, 'temp_min': 60.8, 'temp_max': 60.8, 'pressure': 998, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 34.45, 'deg': 70}, 'clouds': {'all': 75}, 'dt': 1598636041, 'sys': {'type': 1, 'id': 47, 'country': 'GL', 'sunrise': 1598600888, 'sunset': 1598653374}, 'timezone': -7200, 'id': 3421719, 'name': 'Narsaq', 'cod': 200}
# Processing Record 22 of Set 1 | leninskoye
# {'coord': {'lon': 132.62, 'lat': 47.94}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 60.55, 'feels_like': 52.09, 'temp_min': 60.55, 'temp_max': 60.55, 'pressure': 1013, 'humidity': 68, 'sea_level': 1013, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 15.12, 'deg': 53}, 'clouds': {'all': 94}, 'dt': 1598636041, 'sys': {'country': 'RU', 'sunrise': 1598646218, 'sunset': 1598695065}, 'timezone': 36000, 'id': 2020841, 'name': 'Leninskoye', 'cod': 200}
# Processing Record 23 of Set 1 | oistins
# {'coord': {'lon': -59.53, 'lat': 13.07}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 87.8, 'feels_like': 88.25, 'temp_min': 87.8, 'temp_max': 87.8, 'pressure': 1013, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 80}, 'clouds': {'all': 40}, 'dt': 1598636041, 'sys': {'type': 1, 'id': 8772, 'country': 'BB', 'sunrise': 1598608024, 'sunset': 1598652707}, 'timezone': -14400, 'id': 3373652, 'name': 'Oistins', 'cod': 200}
# Processing Record 24 of Set 1 | kapaa
# {'coord': {'lon': -159.32, 'lat': 22.08}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 72.63, 'feels_like': 77.05, 'temp_min': 71.01, 'temp_max': 73.99, 'pressure': 1017, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 300}, 'rain': {'1h': 0.51}, 'clouds': {'all': 90}, 'dt': 1598636042, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1598631568, 'sunset': 1598677052}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# Processing Record 25 of Set 1 | jamestown
# {'coord': {'lon': -79.24, 'lat': 42.1}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 72.75, 'feels_like': 75.34, 'temp_min': 71.6, 'temp_max': 73.99, 'pressure': 1014, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 240}, 'clouds': {'all': 90}, 'dt': 1598635897, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1598611139, 'sunset': 1598659052}, 'timezone': -14400, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# Processing Record 26 of Set 1 | albany
# {'coord': {'lon': -73.97, 'lat': 42.6}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 73, 'feels_like': 75.69, 'temp_min': 72, 'temp_max': 73.99, 'pressure': 1007, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 262, 'gust': 5.99}, 'clouds': {'all': 79}, 'dt': 1598636042, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1598609833, 'sunset': 1598657828}, 'timezone': -14400, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# Processing Record 27 of Set 1 | lyuban
# {'coord': {'lon': 28, 'lat': 52.8}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.89, 'feels_like': 54.95, 'temp_min': 55.89, 'temp_max': 55.89, 'pressure': 1012, 'humidity': 91, 'sea_level': 1012, 'grnd_level': 995}, 'visibility': 10000, 'wind': {'speed': 3.49, 'deg': 342}, 'clouds': {'all': 94}, 'dt': 1598636042, 'sys': {'country': 'BY', 'sunrise': 1598584337, 'sunset': 1598634389}, 'timezone': 10800, 'id': 625721, 'name': "Lyuban'", 'cod': 200}
# Processing Record 28 of Set 1 | bluff
# {'coord': {'lon': 168.33, 'lat': -46.6}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 45, 'feels_like': 35.94, 'temp_min': 45, 'temp_max': 45, 'pressure': 1008, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 194, 'gust': 21.99}, 'clouds': {'all': 40}, 'dt': 1598636042, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1598642584, 'sunset': 1598681561}, 'timezone': 43200, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# Processing Record 29 of Set 1 | tuatapere
# {'coord': {'lon': 167.68, 'lat': -46.13}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 45, 'feels_like': 35.94, 'temp_min': 45, 'temp_max': 45, 'pressure': 1008, 'humidity': 72}, 'visibility': 10000, 'wind': {'speed': 11.01, 'deg': 194, 'gust': 21.99}, 'clouds': {'all': 16}, 'dt': 1598636042, 'sys': {'type': 3, 'id': 2008959, 'country': 'NZ', 'sunrise': 1598642703, 'sunset': 1598681755}, 'timezone': 43200, 'id': 2180815, 'name': 'Tuatapere', 'cod': 200}
# Processing Record 30 of Set 1 | rikitea
# {'coord': {'lon': -134.97, 'lat': -23.12}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 67.93, 'feels_like': 68.5, 'temp_min': 67.93, 'temp_max': 67.93, 'pressure': 1021, 'humidity': 66, 'sea_level': 1021, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 2.39, 'deg': 10}, 'clouds': {'all': 3}, 'dt': 1598636043, 'sys': {'country': 'PF', 'sunrise': 1598627622, 'sunset': 1598669313}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# Processing Record 31 of Set 1 | cabo san lucas
# {'coord': {'lon': -109.91, 'lat': 22.89}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.19, 'feels_like': 86.27, 'temp_min': 77, 'temp_max': 79, 'pressure': 1012, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 230}, 'clouds': {'all': 90}, 'dt': 1598635795, 'sys': {'type': 1, 'id': 7151, 'country': 'MX', 'sunrise': 1598619668, 'sunset': 1598665241}, 'timezone': -21600, 'id': 3985710, 'name': 'Cabo San Lucas', 'cod': 200}
# Processing Record 32 of Set 1 | sarh
# {'coord': {'lon': 18.39, 'lat': 9.14}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 73.09, 'feels_like': 80.4, 'temp_min': 73.09, 'temp_max': 73.09, 'pressure': 1008, 'humidity': 95, 'sea_level': 1008, 'grnd_level': 967}, 'visibility': 10000, 'wind': {'speed': 2.01, 'deg': 358}, 'clouds': {'all': 100}, 'dt': 1598636043, 'sys': {'country': 'TD', 'sunrise': 1598589491, 'sunset': 1598633847}, 'timezone': 3600, 'id': 2425791, 'name': 'Sarh', 'cod': 200}
# Processing Record 33 of Set 1 | ixtapa
# {'coord': {'lon': -105.2, 'lat': 20.7}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.81, 'feels_like': 92.03, 'temp_min': 80.6, 'temp_max': 82.99, 'pressure': 1014, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 30}, 'clouds': {'all': 90}, 'dt': 1598636032, 'sys': {'type': 1, 'id': 7156, 'country': 'MX', 'sunrise': 1598618643, 'sunset': 1598664006}, 'timezone': -18000, 'id': 4004293, 'name': 'Ixtapa', 'cod': 200}
# Processing Record 34 of Set 1 | vaitupu
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 35 of Set 1 | hermanus
# {'coord': {'lon': 19.23, 'lat': -34.42}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 51.01, 'feels_like': 49.12, 'temp_min': 51.01, 'temp_max': 51.01, 'pressure': 1010, 'humidity': 85}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 312, 'gust': 7}, 'clouds': {'all': 73}, 'dt': 1598636043, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1598591213, 'sunset': 1598631722}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# Processing Record 36 of Set 1 | castro
# {'coord': {'lon': -50.01, 'lat': -24.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 77.14, 'feels_like': 75.6, 'temp_min': 77.14, 'temp_max': 77.14, 'pressure': 1015, 'humidity': 44, 'sea_level': 1015, 'grnd_level': 907}, 'visibility': 10000, 'wind': {'speed': 4.68, 'deg': 324}, 'clouds': {'all': 0}, 'dt': 1598636043, 'sys': {'country': 'BR', 'sunrise': 1598607322, 'sunset': 1598648841}, 'timezone': -10800, 'id': 3466704, 'name': 'Castro', 'cod': 200}
# Processing Record 37 of Set 1 | new norfolk
# {'coord': {'lon': 147.06, 'lat': -42.78}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 49.62, 'feels_like': 46.11, 'temp_min': 46, 'temp_max': 53.01, 'pressure': 1016, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 65, 'gust': 5.01}, 'clouds': {'all': 99}, 'dt': 1598636044, 'sys': {'type': 3, 'id': 2031307, 'country': 'AU', 'sunrise': 1598647400, 'sunset': 1598686954}, 'timezone': 36000, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# Processing Record 38 of Set 1 | san cristobal
# {'coord': {'lon': -72.22, 'lat': 7.77}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 89.6, 'feels_like': 90.7, 'temp_min': 89.6, 'temp_max': 89.6, 'pressure': 1015, 'humidity': 55}, 'visibility': 10000, 'wind': {'speed': 12.75, 'deg': 360}, 'clouds': {'all': 20}, 'dt': 1598636044, 'sys': {'type': 1, 'id': 8587, 'country': 'VE', 'sunrise': 1598611294, 'sunset': 1598655528}, 'timezone': -14400, 'id': 3628473, 'name': 'San Cristobal', 'cod': 200}
# Processing Record 39 of Set 1 | port hardy
# {'coord': {'lon': -127.42, 'lat': 50.7}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.2, 'feels_like': 57.56, 'temp_min': 57.2, 'temp_max': 57.2, 'pressure': 1019, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 2.24, 'deg': 0}, 'clouds': {'all': 90}, 'dt': 1598636044, 'sys': {'type': 1, 'id': 1011, 'country': 'CA', 'sunrise': 1598621922, 'sunset': 1598671391}, 'timezone': -25200, 'id': 6111862, 'name': 'Port Hardy', 'cod': 200}
# Processing Record 40 of Set 1 | belushya guba
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 41 of Set 1 | xam nua
# {'coord': {'lon': 104.04, 'lat': 20.42}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 66.29, 'feels_like': 70.07, 'temp_min': 66.29, 'temp_max': 66.29, 'pressure': 1006, 'humidity': 92, 'sea_level': 1006, 'grnd_level': 897}, 'visibility': 10000, 'wind': {'speed': 1.83, 'deg': 200}, 'clouds': {'all': 91}, 'dt': 1598636044, 'sys': {'country': 'LA', 'sunrise': 1598654845, 'sunset': 1598700154}, 'timezone': 25200, 'id': 1652203, 'name': 'Xam Nua', 'cod': 200}
# Processing Record 42 of Set 1 | alepe
# {'coord': {'lon': -3.66, 'lat': 5.5}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 81.7, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1011, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 210}, 'clouds': {'all': 75}, 'dt': 1598636045, 'sys': {'type': 1, 'id': 1162, 'country': 'CI', 'sunrise': 1598594934, 'sunset': 1598638985}, 'timezone': 0, 'id': 2293045, 'name': 'Alépé', 'cod': 200}
# Processing Record 43 of Set 1 | tuy hoa
# {'coord': {'lon': 109.3, 'lat': 13.08}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.29, 'feels_like': 84.69, 'temp_min': 79.29, 'temp_max': 79.29, 'pressure': 1006, 'humidity': 81, 'sea_level': 1006, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 6.71, 'deg': 254}, 'clouds': {'all': 94}, 'dt': 1598636045, 'sys': {'country': 'VN', 'sunrise': 1598653906, 'sunset': 1598698568}, 'timezone': 25200, 'id': 1563281, 'name': 'Tuy Hoa', 'cod': 200}
# Processing Record 44 of Set 1 | port alfred
# {'coord': {'lon': 26.89, 'lat': -33.59}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 58.68, 'feels_like': 55.31, 'temp_min': 58.68, 'temp_max': 58.68, 'pressure': 1009, 'humidity': 68, 'sea_level': 1009, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 5.26, 'deg': 270}, 'clouds': {'all': 0}, 'dt': 1598636045, 'sys': {'country': 'ZA', 'sunrise': 1598589329, 'sunset': 1598629929}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# Processing Record 45 of Set 1 | alberton
# {'coord': {'lon': -64.07, 'lat': 46.82}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 63.97, 'feels_like': 54.43, 'temp_min': 63.97, 'temp_max': 63.97, 'pressure': 1002, 'humidity': 52, 'sea_level': 1002, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 15.28, 'deg': 282}, 'clouds': {'all': 2}, 'dt': 1598636045, 'sys': {'country': 'CA', 'sunrise': 1598607093, 'sunset': 1598655818}, 'timezone': -10800, 'id': 5883166, 'name': 'Alberton', 'cod': 200}
# Processing Record 46 of Set 1 | kalmunai
# {'coord': {'lon': 81.82, 'lat': 7.42}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 81, 'feels_like': 86.83, 'temp_min': 81, 'temp_max': 81, 'pressure': 1008, 'humidity': 79, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 6.85, 'deg': 262}, 'clouds': {'all': 36}, 'dt': 1598636045, 'sys': {'country': 'LK', 'sunrise': 1598574341, 'sunset': 1598618557}, 'timezone': 19800, 'id': 1242110, 'name': 'Kalmunai', 'cod': 200}
# Processing Record 47 of Set 1 | sedelnikovo
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 48 of Set 1 | swan hill
# {'coord': {'lon': 143.55, 'lat': -35.34}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 42.8, 'feels_like': 36.34, 'temp_min': 42.8, 'temp_max': 42.8, 'pressure': 1029, 'humidity': 72, 'sea_level': 1029, 'grnd_level': 1020}, 'visibility': 10000, 'wind': {'speed': 5.77, 'deg': 5}, 'clouds': {'all': 0}, 'dt': 1598636046, 'sys': {'country': 'AU', 'sunrise': 1598647777, 'sunset': 1598688261}, 'timezone': 36000, 'id': 2147756, 'name': 'Swan Hill', 'cod': 200}
# Processing Record 49 of Set 1 | tromso
# {'coord': {'lon': 18.96, 'lat': 69.65}, 'weather': [{'id': 521, 'main': 'Rain', 'description': 'shower rain', 'icon': '09d'}], 'base': 'stations', 'main': {'temp': 48.2, 'feels_like': 40.6, 'temp_min': 48.2, 'temp_max': 48.2, 'pressure': 1009, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 9.17, 'deg': 210}, 'clouds': {'all': 75}, 'dt': 1598636046, 'sys': {'type': 1, 'id': 1681, 'country': 'NO', 'sunrise': 1598582784, 'sunset': 1598640280}, 'timezone': 7200, 'id': 6453316, 'name': 'Tromsø', 'cod': 200}
# Processing Record 50 of Set 1 | hilo
# {'coord': {'lon': -155.09, 'lat': 19.73}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 64.72, 'feels_like': 64.67, 'temp_min': 48, 'temp_max': 71.6, 'pressure': 1016, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 220}, 'clouds': {'all': 1}, 'dt': 1598635804, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1598630664, 'sunset': 1598675927}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# Processing Record 1 of Set 2 | ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 620, 'main': 'Snow', 'description': 'light shower snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 33.8, 'feels_like': 17.6, 'temp_min': 33.8, 'temp_max': 33.8, 'pressure': 985, 'humidity': 86}, 'visibility': 8000, 'wind': {'speed': 21.92, 'deg': 230}, 'clouds': {'all': 75}, 'dt': 1598636046, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1598613798, 'sunset': 1598651143}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# Processing Record 2 of Set 2 | busselton
# {'coord': {'lon': 115.33, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 50.2, 'feels_like': 38.86, 'temp_min': 48.99, 'temp_max': 52, 'pressure': 1011, 'humidity': 67}, 'visibility': 10000, 'wind': {'speed': 16.08, 'deg': 225}, 'clouds': {'all': 3}, 'dt': 1598636046, 'sys': {'type': 3, 'id': 2011706, 'country': 'AU', 'sunrise': 1598654450, 'sunset': 1598695131}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# Processing Record 3 of Set 2 | yomitan
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 4 of Set 2 | nemuro
# {'coord': {'lon': 145.57, 'lat': 43.32}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 67.82, 'feels_like': 69.15, 'temp_min': 67.82, 'temp_max': 67.82, 'pressure': 1006, 'humidity': 94, 'sea_level': 1006, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 7.83, 'deg': 245}, 'clouds': {'all': 30}, 'dt': 1598636047, 'sys': {'country': 'JP', 'sunrise': 1598643512, 'sunset': 1598691557}, 'timezone': 32400, 'id': 2128975, 'name': 'Nemuro', 'cod': 200}
# Processing Record 5 of Set 2 | talant
# {'coord': {'lon': 5.01, 'lat': 47.34}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 62.89, 'feels_like': 56.75, 'temp_min': 61, 'temp_max': 64.4, 'pressure': 1005, 'humidity': 82}, 'visibility': 10000, 'wind': {'speed': 14.99, 'deg': 180}, 'clouds': {'all': 40}, 'dt': 1598636047, 'sys': {'type': 1, 'id': 6586, 'country': 'FR', 'sunrise': 1598590449, 'sunset': 1598639309}, 'timezone': 7200, 'id': 2973510, 'name': 'Talant', 'cod': 200}
# Processing Record 6 of Set 2 | indianapolis
# {'coord': {'lon': -86.16, 'lat': 39.77}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.65, 'feels_like': 79.81, 'temp_min': 75.99, 'temp_max': 84.2, 'pressure': 1011, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 14.99, 'deg': 190}, 'clouds': {'all': 75}, 'dt': 1598635828, 'sys': {'type': 1, 'id': 4533, 'country': 'US', 'sunrise': 1598612976, 'sunset': 1598660536}, 'timezone': -14400, 'id': 4259418, 'name': 'Indianapolis', 'cod': 200}
# Processing Record 7 of Set 2 | alice springs
# {'coord': {'lon': 133.88, 'lat': -23.7}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 46.4, 'feels_like': 39.09, 'temp_min': 46.4, 'temp_max': 46.4, 'pressure': 1023, 'humidity': 28}, 'visibility': 10000, 'wind': {'speed': 3.36, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1598636047, 'sys': {'type': 1, 'id': 9483, 'country': 'AU', 'sunrise': 1598649510, 'sunset': 1598691168}, 'timezone': 34200, 'id': 2077895, 'name': 'Alice Springs', 'cod': 200}
# Processing Record 8 of Set 2 | barrow
# {'coord': {'lon': -156.79, 'lat': 71.29}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 37.4, 'feels_like': 25.66, 'temp_min': 37.4, 'temp_max': 37.4, 'pressure': 1022, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 14.99, 'deg': 80}, 'clouds': {'all': 90}, 'dt': 1598636047, 'sys': {'type': 1, 'id': 7649, 'country': 'US', 'sunrise': 1598624352, 'sunset': 1598683055}, 'timezone': -28800, 'id': 5880054, 'name': 'Barrow', 'cod': 200}
# Processing Record 9 of Set 2 | saskylakh
# {'coord': {'lon': 114.08, 'lat': 71.92}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 51.04, 'feels_like': 47.64, 'temp_min': 51.04, 'temp_max': 51.04, 'pressure': 1015, 'humidity': 70, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 2.66, 'deg': 148}, 'clouds': {'all': 1}, 'dt': 1598636048, 'sys': {'country': 'RU', 'sunrise': 1598645493, 'sunset': 1598704687}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# Processing Record 10 of Set 2 | mogadishu
# {'coord': {'lon': 45.34, 'lat': 2.04}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 77.56, 'feels_like': 77.07, 'temp_min': 77.56, 'temp_max': 77.56, 'pressure': 1011, 'humidity': 82, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 15.9, 'deg': 192}, 'rain': {'1h': 0.13}, 'clouds': {'all': 12}, 'dt': 1598636048, 'sys': {'country': 'SO', 'sunrise': 1598583317, 'sunset': 1598627087}, 'timezone': 10800, 'id': 53654, 'name': 'Mogadishu', 'cod': 200}
# Processing Record 11 of Set 2 | kodiak
# {'coord': {'lon': -152.41, 'lat': 57.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 55.4, 'feels_like': 47.64, 'temp_min': 55.4, 'temp_max': 55.4, 'pressure': 1010, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 300}, 'clouds': {'all': 1}, 'dt': 1598636020, 'sys': {'type': 1, 'id': 7668, 'country': 'US', 'sunrise': 1598627002, 'sunset': 1598678303}, 'timezone': -28800, 'id': 5866583, 'name': 'Saint Paul Harbor', 'cod': 200}
# Processing Record 12 of Set 2 | bethel
# {'coord': {'lon': -73.41, 'lat': 41.37}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.05, 'feels_like': 80.02, 'temp_min': 77, 'temp_max': 81, 'pressure': 1011, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 5.79, 'deg': 291}, 'clouds': {'all': 90}, 'dt': 1598636048, 'sys': {'type': 1, 'id': 3888, 'country': 'US', 'sunrise': 1598609795, 'sunset': 1598657598}, 'timezone': -14400, 'id': 5282297, 'name': 'Bethel', 'cod': 200}
# Processing Record 13 of Set 2 | garmsar
# {'coord': {'lon': 52.34, 'lat': 35.22}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 75.79, 'feels_like': 69.39, 'temp_min': 75.79, 'temp_max': 75.79, 'pressure': 1009, 'humidity': 19, 'sea_level': 1009, 'grnd_level': 915}, 'visibility': 10000, 'wind': {'speed': 4.68, 'deg': 78}, 'clouds': {'all': 0}, 'dt': 1598636048, 'sys': {'country': 'IR', 'sunrise': 1598580027, 'sunset': 1598627018}, 'timezone': 16200, 'id': 133964, 'name': 'Garmsār', 'cod': 200}
# Processing Record 14 of Set 2 | puerto ayora
# {'coord': {'lon': -90.35, 'lat': -0.74}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 68.22, 'feels_like': 60.24, 'temp_min': 66, 'temp_max': 71.6, 'pressure': 1017, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 19.46, 'deg': 120}, 'clouds': {'all': 75}, 'dt': 1598636048, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1598615989, 'sunset': 1598659533}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# Processing Record 15 of Set 2 | bredasdorp
# {'coord': {'lon': 20.04, 'lat': -34.53}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 53.6, 'feels_like': 48.6, 'temp_min': 53.6, 'temp_max': 53.6, 'pressure': 1010, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 330}, 'clouds': {'all': 86}, 'dt': 1598636049, 'sys': {'type': 1, 'id': 1966, 'country': 'ZA', 'sunrise': 1598591025, 'sunset': 1598631521}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# Processing Record 16 of Set 2 | atuona
# {'coord': {'lon': -139.03, 'lat': -9.8}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 77.88, 'feels_like': 73.85, 'temp_min': 77.88, 'temp_max': 77.88, 'pressure': 1014, 'humidity': 79, 'sea_level': 1014, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 21.47, 'deg': 103}, 'rain': {'1h': 0.51}, 'clouds': {'all': 48}, 'dt': 1598635841, 'sys': {'country': 'PF', 'sunrise': 1598628031, 'sunset': 1598670853}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# Processing Record 17 of Set 2 | esperance
# {'coord': {'lon': 121.9, 'lat': -33.87}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.2, 'feels_like': 49.75, 'temp_min': 57.2, 'temp_max': 57.2, 'pressure': 1010, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 16.11, 'deg': 290}, 'clouds': {'all': 71}, 'dt': 1598636049, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1598652886, 'sunset': 1598693541}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# Processing Record 18 of Set 2 | cherskiy
# {'coord': {'lon': 161.3, 'lat': 68.75}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 36.7, 'feels_like': 30.34, 'temp_min': 36.7, 'temp_max': 36.7, 'pressure': 1022, 'humidity': 93, 'sea_level': 1022, 'grnd_level': 1022}, 'visibility': 10000, 'wind': {'speed': 5.73, 'deg': 349}, 'clouds': {'all': 11}, 'dt': 1598636049, 'sys': {'country': 'RU', 'sunrise': 1598635523, 'sunset': 1598691996}, 'timezone': 39600, 'id': 2126199, 'name': 'Cherskiy', 'cod': 200}
# Processing Record 19 of Set 2 | aklavik
# {'coord': {'lon': -135.01, 'lat': 68.22}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 46.4, 'feels_like': 40.69, 'temp_min': 46.4, 'temp_max': 46.4, 'pressure': 1018, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 110}, 'clouds': {'all': 75}, 'dt': 1598636049, 'sys': {'type': 1, 'id': 821, 'country': 'CA', 'sunrise': 1598620387, 'sunset': 1598676567}, 'timezone': -21600, 'id': 5882953, 'name': 'Aklavik', 'cod': 200}
# Processing Record 20 of Set 2 | nome
# {'coord': {'lon': -165.41, 'lat': 64.5}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.3, 'feels_like': 48.2, 'temp_min': 51.01, 'temp_max': 51.8, 'pressure': 1010, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 4.52, 'deg': 5}, 'clouds': {'all': 90}, 'dt': 1598636049, 'sys': {'type': 1, 'id': 7770, 'country': 'US', 'sunrise': 1598628801, 'sunset': 1598682742}, 'timezone': -28800, 'id': 5870133, 'name': 'Nome', 'cod': 200}
# Processing Record 21 of Set 2 | upernavik
# {'coord': {'lon': -56.15, 'lat': 72.79}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 41.25, 'feels_like': 29.62, 'temp_min': 41.25, 'temp_max': 41.25, 'pressure': 1012, 'humidity': 67, 'sea_level': 1012, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 14.07, 'deg': 358}, 'clouds': {'all': 0}, 'dt': 1598636050, 'sys': {'country': 'GL', 'sunrise': 1598599284, 'sunset': 1598659825}, 'timezone': -7200, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# Processing Record 22 of Set 2 | temaraia
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 23 of Set 2 | bambous virieux
# {'coord': {'lon': 57.76, 'lat': -20.34}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.7, 'feels_like': 71.56, 'temp_min': 72, 'temp_max': 73.4, 'pressure': 1020, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 10.29, 'deg': 90}, 'clouds': {'all': 75}, 'dt': 1598636050, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1598581269, 'sunset': 1598623174}, 'timezone': 14400, 'id': 1106677, 'name': 'Bambous Virieux', 'cod': 200}
# Processing Record 24 of Set 2 | ribeira grande
# {'coord': {'lon': -28.7, 'lat': 38.52}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 79.12, 'temp_min': 77, 'temp_max': 77, 'pressure': 1023, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 12.75, 'deg': 240}, 'clouds': {'all': 40}, 'dt': 1598636050, 'sys': {'type': 1, 'id': 6883, 'country': 'PT', 'sunrise': 1598599266, 'sunset': 1598646670}, 'timezone': 0, 'id': 3372707, 'name': 'Ribeira Grande', 'cod': 200}
# Processing Record 25 of Set 2 | pevek
# {'coord': {'lon': 170.31, 'lat': 69.7}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 39.22, 'feels_like': 34.57, 'temp_min': 39.22, 'temp_max': 39.22, 'pressure': 1023, 'humidity': 87, 'sea_level': 1023, 'grnd_level': 1018}, 'visibility': 10000, 'wind': {'speed': 2.91, 'deg': 128}, 'clouds': {'all': 22}, 'dt': 1598636050, 'sys': {'country': 'RU', 'sunrise': 1598632987, 'sunset': 1598690209}, 'timezone': 43200, 'id': 2122090, 'name': 'Pevek', 'cod': 200}
# Processing Record 26 of Set 2 | east london
# {'coord': {'lon': 27.91, 'lat': -33.02}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 57.2, 'feels_like': 53.92, 'temp_min': 57.2, 'temp_max': 57.2, 'pressure': 1010, 'humidity': 76}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 280}, 'clouds': {'all': 32}, 'dt': 1598636050, 'sys': {'type': 1, 'id': 1912, 'country': 'ZA', 'sunrise': 1598589053, 'sunset': 1598629716}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# Processing Record 27 of Set 2 | humaita
# {'coord': {'lon': -63.02, 'lat': -7.51}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 99.16, 'feels_like': 102.4, 'temp_min': 99.16, 'temp_max': 99.16, 'pressure': 1008, 'humidity': 32, 'sea_level': 1008, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 2.91, 'deg': 108}, 'clouds': {'all': 72}, 'dt': 1598636051, 'sys': {'country': 'BR', 'sunrise': 1598609702, 'sunset': 1598652704}, 'timezone': -14400, 'id': 3664078, 'name': 'Humaitá', 'cod': 200}
# Processing Record 28 of Set 2 | salekhard
# {'coord': {'lon': 66.6, 'lat': 66.53}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 55.15, 'feels_like': 48.42, 'temp_min': 55.15, 'temp_max': 55.15, 'pressure': 1010, 'humidity': 80, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 11.65, 'deg': 302}, 'clouds': {'all': 100}, 'dt': 1598636051, 'sys': {'country': 'RU', 'sunrise': 1598572433, 'sunset': 1598627768}, 'timezone': 18000, 'id': 1493197, 'name': 'Salekhard', 'cod': 200}
# Processing Record 29 of Set 2 | venkatagiri
# {'coord': {'lon': 79.58, 'lat': 13.97}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 85.44, 'feels_like': 92.62, 'temp_min': 85.44, 'temp_max': 85.44, 'pressure': 1006, 'humidity': 61, 'sea_level': 1006, 'grnd_level': 998}, 'visibility': 10000, 'wind': {'speed': 1.19, 'deg': 89}, 'clouds': {'all': 100}, 'dt': 1598636051, 'sys': {'country': 'IN', 'sunrise': 1598574597, 'sunset': 1598619375}, 'timezone': 19800, 'id': 1253251, 'name': 'Venkatagiri', 'cod': 200}
# Processing Record 30 of Set 2 | sao filipe
# {'coord': {'lon': -24.5, 'lat': 14.9}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 79.03, 'feels_like': 86.67, 'temp_min': 79.03, 'temp_max': 79.03, 'pressure': 1010, 'humidity': 82, 'sea_level': 1010, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 2.86, 'deg': 317}, 'rain': {'1h': 0.26}, 'clouds': {'all': 91}, 'dt': 1598636051, 'sys': {'country': 'CV', 'sunrise': 1598599537, 'sunset': 1598644384}, 'timezone': -3600, 'id': 3374210, 'name': 'São Filipe', 'cod': 200}
# Processing Record 31 of Set 2 | khatanga
# {'coord': {'lon': 102.5, 'lat': 71.97}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 54.7, 'feels_like': 49.14, 'temp_min': 54.7, 'temp_max': 54.7, 'pressure': 1012, 'humidity': 58, 'sea_level': 1012, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.02, 'deg': 115}, 'clouds': {'all': 58}, 'dt': 1598636051, 'sys': {'country': 'RU', 'sunrise': 1598648256, 'sunset': 1598707482}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# Processing Record 32 of Set 2 | ilo
# {'coord': {'lon': -71.34, 'lat': -17.64}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 60.33, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1019, 'humidity': 88}, 'visibility': 8000, 'wind': {'speed': 9.17, 'deg': 160}, 'clouds': {'all': 90}, 'dt': 1598636052, 'sys': {'type': 1, 'id': 8671, 'country': 'PE', 'sunrise': 1598612118, 'sunset': 1598654281}, 'timezone': -18000, 'id': 3938415, 'name': 'Ilo', 'cod': 200}
# Processing Record 33 of Set 2 | nouadhibou
# {'coord': {'lon': -17.03, 'lat': 20.93}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 87.17, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1007, 'humidity': 70}, 'visibility': 8000, 'wind': {'speed': 11.41, 'deg': 290}, 'clouds': {'all': 0}, 'dt': 1598636052, 'sys': {'type': 1, 'id': 2444, 'country': 'MR', 'sunrise': 1598597467, 'sunset': 1598642869}, 'timezone': 0, 'id': 2377457, 'name': 'Nouadhibou', 'cod': 200}
# Processing Record 34 of Set 2 | talnakh
# {'coord': {'lon': 88.4, 'lat': 69.49}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 59, 'feels_like': 55.54, 'temp_min': 59, 'temp_max': 59, 'pressure': 1009, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 200}, 'clouds': {'all': 97}, 'dt': 1598636052, 'sys': {'type': 1, 'id': 8951, 'country': 'RU', 'sunrise': 1598652787, 'sunset': 1598709717}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# Processing Record 35 of Set 2 | tateyama
# {'coord': {'lon': 139.87, 'lat': 34.98}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.51, 'feels_like': 91.13, 'temp_min': 79, 'temp_max': 82, 'pressure': 1013, 'humidity': 90}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 264, 'gust': 3}, 'clouds': {'all': 0}, 'dt': 1598636052, 'sys': {'type': 3, 'id': 20334, 'country': 'JP', 'sunrise': 1598645469, 'sunset': 1598692335}, 'timezone': 32400, 'id': 1850523, 'name': 'Tateyama', 'cod': 200}
# Processing Record 36 of Set 2 | hvolsvollur
# {'coord': {'lon': -20.22, 'lat': 63.75}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 50.99, 'feels_like': 38.64, 'temp_min': 50, 'temp_max': 51.8, 'pressure': 1019, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 20.8, 'deg': 290}, 'clouds': {'all': 75}, 'dt': 1598636052, 'sys': {'type': 1, 'id': 93, 'country': 'IS', 'sunrise': 1598594068, 'sunset': 1598647799}, 'timezone': 0, 'id': 3415720, 'name': 'Hvolsvollur', 'cod': 200}
# Processing Record 37 of Set 2 | lompoc
# {'coord': {'lon': -120.46, 'lat': 34.64}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.31, 'feels_like': 55.74, 'temp_min': 55.4, 'temp_max': 59, 'pressure': 1012, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 240}, 'clouds': {'all': 90}, 'dt': 1598635777, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1598621557, 'sunset': 1598668415}, 'timezone': -25200, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# Processing Record 38 of Set 2 | nador
# {'coord': {'lon': -2.93, 'lat': 35.17}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 88.48, 'feels_like': 81.16, 'temp_min': 86, 'temp_max': 91.4, 'pressure': 1007, 'humidity': 45}, 'visibility': 10000, 'wind': {'speed': 21.92, 'deg': 270}, 'clouds': {'all': 20}, 'dt': 1598636053, 'sys': {'type': 1, 'id': 2380, 'country': 'MA', 'sunrise': 1598593302, 'sunset': 1598640267}, 'timezone': 3600, 'id': 2541479, 'name': 'Nador', 'cod': 200}
# Processing Record 39 of Set 2 | marcona
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 40 of Set 2 | fukue
# {'coord': {'lon': 128.84, 'lat': 32.69}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 81.88, 'feels_like': 85.24, 'temp_min': 81.88, 'temp_max': 81.88, 'pressure': 1008, 'humidity': 86, 'sea_level': 1008, 'grnd_level': 1008}, 'visibility': 10000, 'wind': {'speed': 14.83, 'deg': 167}, 'clouds': {'all': 7}, 'dt': 1598636053, 'sys': {'country': 'JP', 'sunrise': 1598648256, 'sunset': 1598694841}, 'timezone': 32400, 'id': 1863997, 'name': 'Fukuechō', 'cod': 200}
# Processing Record 41 of Set 2 | illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 42 of Set 2 | port lincoln
# ...
# Processing Record 38 of Set 15 | chicama
# {'coord': {'lon': -79.15, 'lat': -7.84}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 73.9, 'feels_like': 69.33, 'temp_min': 73.9, 'temp_max': 73.9, 'pressure': 1016, 'humidity': 53, 'sea_level': 1016, 'grnd_level': 1001}, 'visibility': 10000, 'wind': {'speed': 11.27, 'deg': 206}, 'clouds': {'all': 15}, 'dt': 1598636169, 'sys': {'country': 'PE', 'sunrise': 1598613586, 'sunset': 1598656562}, 'timezone': -18000, 'id': 3698359, 'name': 'Chicama', 'cod': 200}
# Processing Record 39 of Set 15 | kholodnyy
# {'coord': {'lon': 147.95, 'lat': 62.72}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 29.93, 'feels_like': 24.24, 'temp_min': 29.93, 'temp_max': 29.93, 'pressure': 1022, 'humidity': 97, 'sea_level': 1022, 'grnd_level': 945}, 'visibility': 10000, 'wind': {'speed': 3.04, 'deg': 42}, 'clouds': {'all': 89}, 'dt': 1598636169, 'sys': {'country': 'RU', 'sunrise': 1598640431, 'sunset': 1598693495}, 'timezone': 39600, 'id': 2124611, 'name': 'Kholodnyy', 'cod': 200}
# Processing Record 40 of Set 15 | dangriga
# {'coord': {'lon': -88.23, 'lat': 16.97}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 90.97, 'feels_like': 102.43, 'temp_min': 89.6, 'temp_max': 93.99, 'pressure': 1013, 'humidity': 79}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 150}, 'clouds': {'all': 75}, 'dt': 1598636169, 'sys': {'type': 1, 'id': 7263, 'country': 'BZ', 'sunrise': 1598614741, 'sunset': 1598659764}, 'timezone': -21600, 'id': 3582228, 'name': 'Stann Creek Town', 'cod': 200}
# Processing Record 41 of Set 15 | kendari
# {'coord': {'lon': 122.5, 'lat': -3.94}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 72.48, 'feels_like': 78.8, 'temp_min': 72.48, 'temp_max': 72.48, 'pressure': 1010, 'humidity': 89, 'sea_level': 1010, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 1.5, 'deg': 191}, 'clouds': {'all': 50}, 'dt': 1598635920, 'sys': {'country': 'ID', 'sunrise': 1598651423, 'sunset': 1598694717}, 'timezone': 28800, 'id': 1640344, 'name': 'Kendari', 'cod': 200}
# Processing Record 42 of Set 15 | sao jose da coroa grande
# {'coord': {'lon': -35.15, 'lat': -8.9}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.75, 'feels_like': 82.18, 'temp_min': 79.75, 'temp_max': 79.75, 'pressure': 1015, 'humidity': 69, 'sea_level': 1015, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 8.08, 'deg': 138}, 'clouds': {'all': 83}, 'dt': 1598636170, 'sys': {'country': 'BR', 'sunrise': 1598603072, 'sunset': 1598645959}, 'timezone': -10800, 'id': 3388456, 'name': 'São José da Coroa Grande', 'cod': 200}
# Processing Record 43 of Set 15 | tocopilla
# {'coord': {'lon': -70.2, 'lat': -22.09}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 66.74, 'feels_like': 59.63, 'temp_min': 66.74, 'temp_max': 66.74, 'pressure': 1016, 'humidity': 53, 'sea_level': 1016, 'grnd_level': 1012}, 'visibility': 5715, 'wind': {'speed': 12.33, 'deg': 215}, 'clouds': {'all': 16}, 'dt': 1598636170, 'sys': {'country': 'CL', 'sunrise': 1598612040, 'sunset': 1598653812}, 'timezone': -14400, 'id': 3869716, 'name': 'Tocopilla', 'cod': 200}
# Processing Record 44 of Set 15 | coruripe
# {'coord': {'lon': -36.18, 'lat': -10.13}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.04, 'feels_like': 79.54, 'temp_min': 78.04, 'temp_max': 78.04, 'pressure': 1015, 'humidity': 77, 'sea_level': 1015, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 11.1, 'deg': 140}, 'clouds': {'all': 91}, 'dt': 1598636170, 'sys': {'country': 'BR', 'sunrise': 1598603369, 'sunset': 1598646156}, 'timezone': -10800, 'id': 3465329, 'name': 'Coruripe', 'cod': 200}
# Processing Record 45 of Set 15 | garoua boulai
# {'coord': {'lon': 14.55, 'lat': 5.88}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 67.17, 'feels_like': 70.92, 'temp_min': 67.17, 'temp_max': 67.17, 'pressure': 1011, 'humidity': 98, 'sea_level': 1011, 'grnd_level': 899}, 'visibility': 10000, 'wind': {'speed': 3.98, 'deg': 238}, 'rain': {'1h': 0.8}, 'clouds': {'all': 93}, 'dt': 1598636170, 'sys': {'country': 'CM', 'sunrise': 1598590548, 'sunset': 1598634632}, 'timezone': 3600, 'id': 2231319, 'name': 'Garoua Boulaï', 'cod': 200}
# Processing Record 46 of Set 15 | nantucket
# {'coord': {'lon': -70.1, 'lat': 41.28}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 74.64, 'feels_like': 73.69, 'temp_min': 73.99, 'temp_max': 75.2, 'pressure': 1009, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 270}, 'clouds': {'all': 1}, 'dt': 1598636171, 'sys': {'type': 1, 'id': 3218, 'country': 'US', 'sunrise': 1598609007, 'sunset': 1598656797}, 'timezone': -14400, 'id': 4944903, 'name': 'Nantucket', 'cod': 200}
# Processing Record 47 of Set 15 | bolungarvik
# {'cod': '404', 'message': 'city not found'}
# City not found. Skipping...
# Processing Record 48 of Set 15 | hasaki
# {'coord': {'lon': 140.83, 'lat': 35.73}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 78.87, 'feels_like': 87.78, 'temp_min': 78.8, 'temp_max': 79, 'pressure': 1011, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 180}, 'clouds': {'all': 20}, 'dt': 1598636171, 'sys': {'type': 1, 'id': 7955, 'country': 'JP', 'sunrise': 1598645191, 'sunset': 1598692152}, 'timezone': 32400, 'id': 2112802, 'name': 'Hasaki', 'cod': 200}
# Processing Record 49 of Set 15 | varhaug
# {'coord': {'lon': 5.65, 'lat': 58.61}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 58.68, 'feels_like': 54.88, 'temp_min': 57.99, 'temp_max': 59, 'pressure': 995, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 28}, 'clouds': {'all': 70}, 'dt': 1598636171, 'sys': {'type': 3, 'id': 2034752, 'country': 'NO', 'sunrise': 1598588877, 'sunset': 1598640575}, 'timezone': 7200, 'id': 3132644, 'name': 'Varhaug', 'cod': 200}
# Processing Record 50 of Set 15 | vizinga
# {'coord': {'lon': 50.1, 'lat': 61.07}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 58.35, 'feels_like': 56.08, 'temp_min': 58.35, 'temp_max': 58.35, 'pressure': 1010, 'humidity': 88, 'sea_level': 1010, 'grnd_level': 999}, 'visibility': 10000, 'wind': {'speed': 6.67, 'deg': 98}, 'clouds': {'all': 100}, 'dt': 1598636171, 'sys': {'country': 'RU', 'sunrise': 1598577743, 'sunset': 1598630377}, 'timezone': 10800, 'id': 473263, 'name': 'Vizinga', 'cod': 200}
# Processing Record 1 of Set 16 | tanout
# {'coord': {'lon': 8.89, 'lat': 14.97}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 88.66, 'feels_like': 88.27, 'temp_min': 88.66, 'temp_max': 88.66, 'pressure': 1006, 'humidity': 46, 'sea_level': 1006, 'grnd_level': 948}, 'visibility': 10000, 'wind': {'speed': 10.25, 'deg': 247}, 'clouds': {'all': 86}, 'dt': 1598636171, 'sys': {'country': 'NE', 'sunrise': 1598591520, 'sunset': 1598636377}, 'timezone': 3600, 'id': 2439155, 'name': 'Tanout', 'cod': 200}
# Processing Record 2 of Set 16 | nabire
# {'coord': {'lon': 135.48, 'lat': -3.37}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 76.57, 'feels_like': 82.89, 'temp_min': 76.57, 'temp_max': 76.57, 'pressure': 1008, 'humidity': 88, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 4.9, 'deg': 171}, 'rain': {'1h': 0.7}, 'clouds': {'all': 98}, 'dt': 1598636172, 'sys': {'country': 'ID', 'sunrise': 1598648286, 'sunset': 1598691624}, 'timezone': 32400, 'id': 1634614, 'name': 'Nabire', 'cod': 200}
# Processing Record 3 of Set 16 | qena
# {'coord': {'lon': 32.72, 'lat': 26.16}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 91.4, 'feels_like': 88.07, 'temp_min': 91.4, 'temp_max': 91.4, 'pressure': 1003, 'humidity': 24}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1598636172, 'sys': {'type': 1, 'id': 2516, 'country': 'EG', 'sunrise': 1598585263, 'sunset': 1598631198}, 'timezone': 7200, 'id': 350550, 'name': 'Qena', 'cod': 200}
# Processing Record 4 of Set 16 | dossor
# {'coord': {'lon': 52.98, 'lat': 47.53}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.05, 'feels_like': 75.58, 'temp_min': 79.05, 'temp_max': 79.05, 'pressure': 1013, 'humidity': 22, 'sea_level': 1013, 'grnd_level': 1015}, 'visibility': 10000, 'wind': {'speed': 1.23, 'deg': 3}, 'clouds': {'all': 100}, 'dt': 1598636172, 'sys': {'country': 'KZ', 'sunrise': 1598578908, 'sunset': 1598627830}, 'timezone': 18000, 'id': 610023, 'name': 'Dossor', 'cod': 200}
# Processing Record 5 of Set 16 | shiraz
# {'coord': {'lon': 52.54, 'lat': 29.6}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 81.18, 'temp_min': 86, 'temp_max': 86, 'pressure': 1012, 'humidity': 20}, 'visibility': 10000, 'wind': {'speed': 4.7, 'deg': 320}, 'clouds': {'all': 20}, 'dt': 1598635895, 'sys': {'type': 1, 'id': 7500, 'country': 'IR', 'sunrise': 1598580317, 'sunset': 1598626632}, 'timezone': 16200, 'id': 115019, 'name': 'Shiraz', 'cod': 200}
# Processing Record 6 of Set 16 | aitape
# {'coord': {'lon': 142.35, 'lat': -3.14}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.5, 'feels_like': 84.87, 'temp_min': 79.5, 'temp_max': 79.5, 'pressure': 1006, 'humidity': 83, 'sea_level': 1006, 'grnd_level': 1006}, 'visibility': 5476, 'wind': {'speed': 7.7, 'deg': 122}, 'clouds': {'all': 100}, 'dt': 1598636172, 'sys': {'country': 'PG', 'sunrise': 1598646629, 'sunset': 1598689985}, 'timezone': 36000, 'id': 2101169, 'name': 'Aitape', 'cod': 200}
# Processing Record 7 of Set 16 | mbandaka
# {'coord': {'lon': 18.26, 'lat': 0.05}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 71.49, 'feels_like': 76.28, 'temp_min': 71.49, 'temp_max': 71.49, 'pressure': 1009, 'humidity': 89, 'sea_level': 1009, 'grnd_level': 973}, 'visibility': 10000, 'wind': {'speed': 3.38, 'deg': 301}, 'clouds': {'all': 70}, 'dt': 1598636044, 'sys': {'country': 'CD', 'sunrise': 1598589896, 'sunset': 1598633504}, 'timezone': 3600, 'id': 2312895, 'name': 'Mbandaka', 'cod': 200}
# Processing Record 8 of Set 16 | coahuayana
# {'coord': {'lon': -103.68, 'lat': 18.73}, 'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}], 'base': 'stations', 'main': {'temp': 69.8, 'feels_like': 71.44, 'temp_min': 69.8, 'temp_max': 69.8, 'pressure': 1020, 'humidity': 77}, 'visibility': 4828, 'wind': {'speed': 4.45, 'deg': 269}, 'clouds': {'all': 90}, 'dt': 1598636173, 'sys': {'type': 1, 'id': 7116, 'country': 'MX', 'sunrise': 1598618370, 'sunset': 1598663550}, 'timezone': -18000, 'id': 4013679, 'name': 'Coahuayana Viejo', 'cod': 200}
# Processing Record 9 of Set 16 | kabalo
# {'coord': {'lon': 26.92, 'lat': -6.05}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 86.74, 'feels_like': 87.87, 'temp_min': 86.74, 'temp_max': 86.74, 'pressure': 1007, 'humidity': 37, 'sea_level': 1007, 'grnd_level': 947}, 'visibility': 10000, 'wind': {'speed': 2.08, 'deg': 88}, 'clouds': {'all': 27}, 'dt': 1598636173, 'sys': {'country': 'CD', 'sunrise': 1598588065, 'sunset': 1598631179}, 'timezone': 7200, 'id': 215668, 'name': 'Kabalo', 'cod': 200}
# Processing Record 10 of Set 16 | ucluelet
# {'coord': {'lon': -125.55, 'lat': 48.93}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 61.57, 'feels_like': 61.39, 'temp_min': 60.8, 'temp_max': 62.01, 'pressure': 1018, 'humidity': 93}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 170}, 'clouds': {'all': 40}, 'dt': 1598636173, 'sys': {'type': 1, 'id': 735, 'country': 'CA', 'sunrise': 1598621658, 'sunset': 1598670757}, 'timezone': -25200, 'id': 6171633, 'name': 'Ucluelet', 'cod': 200}
# Processing Record 11 of Set 16 | broken hill
# {'coord': {'lon': 141.43, 'lat': -31.95}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 48.2, 'feels_like': 37.71, 'temp_min': 48.2, 'temp_max': 48.2, 'pressure': 1027, 'humidity': 46}, 'visibility': 10000, 'wind': {'speed': 11.41, 'deg': 40}, 'clouds': {'all': 0}, 'dt': 1598636173, 'sys': {'type': 1, 'id': 9491, 'country': 'AU', 'sunrise': 1598648101, 'sunset': 1598688954}, 'timezone': 34200, 'id': 2173911, 'name': 'Broken Hill', 'cod': 200}
# Processing Record 12 of Set 16 | olafsvik
# {'coord': {'lon': -23.71, 'lat': 64.89}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 42.39, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1017, 'humidity': 83, 'sea_level': 1017, 'grnd_level': 1013}, 'visibility': 10000, 'wind': {'speed': 15.39, 'deg': 262}, 'clouds': {'all': 100}, 'dt': 1598636173, 'sys': {'country': 'IS', 'sunrise': 1598594621, 'sunset': 1598648920}, 'timezone': 0, 'id': 3414079, 'name': 'Olafsvik', 'cod': 200}
# Processing Record 13 of Set 16 | wagar
# {'coord': {'lon': 36.2, 'lat': 16.15}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 92.71, 'feels_like': 92.68, 'temp_min': 92.71, 'temp_max': 92.71, 'pressure': 1006, 'humidity': 36, 'sea_level': 1006, 'grnd_level': 960}, 'visibility': 10000, 'wind': {'speed': 7.11, 'deg': 267}, 'rain': {'1h': 0.52}, 'clouds': {'all': 5}, 'dt': 1598636174, 'sys': {'country': 'SD', 'sunrise': 1598584912, 'sunset': 1598629879}, 'timezone': 7200, 'id': 364027, 'name': 'Wagar', 'cod': 200}
# Processing Record 14 of Set 16 | jalu
# {'coord': {'lon': 21.55, 'lat': 29.03}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 87.84, 'feels_like': 84.06, 'temp_min': 87.84, 'temp_max': 87.84, 'pressure': 1007, 'humidity': 28, 'sea_level': 1007, 'grnd_level': 1003}, 'visibility': 10000, 'wind': {'speed': 7.16, 'deg': 45}, 'clouds': {'all': 0}, 'dt': 1598636174, 'sys': {'country': 'LY', 'sunrise': 1598587790, 'sunset': 1598634032}, 'timezone': 7200, 'id': 86049, 'name': 'Jalu', 'cod': 200}
# Processing Record 15 of Set 16 | fuyang
# {'coord': {'lon': 115.82, 'lat': 32.9}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 72.14, 'feels_like': 77.5, 'temp_min': 72.14, 'temp_max': 72.14, 'pressure': 1006, 'humidity': 93, 'sea_level': 1006, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 4.03, 'deg': 92}, 'rain': {'1h': 0.648}, 'clouds': {'all': 0}, 'dt': 1598636174, 'sys': {'country': 'CN', 'sunrise': 1598651370, 'sunset': 1598697976}, 'timezone': 28800, 'id': 1810845, 'name': 'Fuyang', 'cod': 200}
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 700

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Current Description    Lat     Lng  Max Temp  Humidity  \
# 0           Tiksi    scattered clouds  71.69  128.87     41.99        80
# 1       Itum-Kale    scattered clouds  42.74   45.58     64.94        59
# 2           Kutum       broken clouds  14.20   24.67     79.12        55
# 3        Pochutla                mist  15.74  -96.47     75.20        69
# 4       Hithadhoo     overcast clouds  -0.60   73.08     79.48        70
# 5           Tahta           clear sky  26.77   31.50     93.20        23
# 6           Kroya       broken clouds  -7.63  109.25     75.56        88
# 7        San Juan           clear sky -31.54  -68.54     73.04        20
# 8           Vaini    scattered clouds -21.20 -175.20     73.40        88
# 9  Saint-Philippe       broken clouds -21.36   55.77     73.40        69
#
#    Cloudiness  Wind Speed Country
# 0          46        7.74      RU
# 1          37        4.70      RU
# 2          79        9.51      SD
# 3          90        5.82      MX
# 4         100       11.41      MV
# 5           0       10.29      EG
# 6          57        7.09      ID
# 7           0        7.70      AR
# 8          40       10.29      TO
# 9          75        4.70      RE

# %%
city_data_columns = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[city_data_columns]

city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Tiksi      RU  71.69  128.87     41.99        80          46
# 1       Itum-Kale      RU  42.74   45.58     64.94        59          37
# 2           Kutum      SD  14.20   24.67     79.12        55          79
# 3        Pochutla      MX  15.74  -96.47     75.20        69          90
# 4       Hithadhoo      MV  -0.60   73.08     79.48        70         100
# 5           Tahta      EG  26.77   31.50     93.20        23           0
# 6           Kroya      ID  -7.63  109.25     75.56        88          57
# 7        San Juan      AR -31.54  -68.54     73.04        20           0
# 8           Vaini      TO -21.20 -175.20     73.40        88          40
# 9  Saint-Philippe      RE -21.36   55.77     73.40        69          75
#
#    Wind Speed Current Description
# 0        7.74    scattered clouds
# 1        4.70    scattered clouds
# 2        9.51       broken clouds
# 3        5.82                mist
# 4       11.41     overcast clouds
# 5       10.29           clear sky
# 6        7.09       broken clouds
# 7        7.70           clear sky
# 8       10.29    scattered clouds
# 9        4.70       broken clouds

# %%
# create the output file (csv)
output_data_file = "WeatherPy_Database.csv"

# export the city_data into a csv
city_data_df.to_csv(output_data_file, index_label="City_ID")
